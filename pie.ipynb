# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.array([45, 5, 15, 35])
mylabels = ["Beer", "Vodka", "Vine", "Tea"]
myexplode = [0.1, 0, 0, 0]

# %%
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()
